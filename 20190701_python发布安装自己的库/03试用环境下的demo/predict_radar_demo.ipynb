# %% [markdown]
# # predict_radar_demo

# %% [markdown]
# This is a demo for predicting radar.

# %% [markdown]
# step01 upload your radar data.
# upload dir: radar_predict/data/    name:*.zip

# %%
import os
import radar_test
#import mapfolium5 as mapradar

# %% [markdown]
# step02 preprocessing test radar data.
# unzip analysis judgement resize and so on

# %%
os.system("rm -rf ./data/radar500_train001")
# Out:
# 0

# %%
os.system("unzip ./data/*.zip -d ./data/")
# Out:
# 0

# %% [markdown]
# step03 load predict network and model param

# %% [markdown]
# step must be [0,6]

# %%
radar_test.predict(step = 6)
# Out:
# **********loading data**********
# **************mode: test **************
# load data... data/radar500_train001
# data areas  10
# gen index
# len(frames_file_name) : 130
# there are 10 sequences
# there are 130 pictures
# **********loading network and  models**********
# num_hidden : [128, 64, 64, 64]
# gen_ims.shape (1, 12, 50, 50, 16)
# ckpt.model_checkpoint_path model/radar_predrnn_pp/model.ckpt-10000
# INFO:tensorflow:Restoring parameters from model/radar_predrnn_pp/model.ckpt-10000
# **********predicting**********
# seq_id 1 is predicting
# seq_id 2 is predicting
# seq_id 3 is predicting
# seq_id 4 is predicting
# seq_id 5 is predicting
# seq_id 6 is predicting
# seq_id 7 is predicting
# seq_id 8 is predicting
# seq_id 9 is predicting
# seq_id 10 is predicting
# mse avg per frame: 4900.269
# frame 1 mse 2675.0562
# frame 2 mse 3667.8882
# frame 3 mse 4546.6606
# frame 4 mse 5487.7676
# frame 5 mse 6207.634
# frame 6 mse 6816.607
# ssim avg per frame: 0.57325155
# ...

# %% [markdown]
# step04 model predict and show the results

# %%
radar_test.plt_show_result()

# %% [markdown]
# step05 Click follow link to download results

# %%
os.system("tar -cvzf results.tar.gz ./results")
# Out:
# 0

# %% [markdown]
# http://103.254.67.181:10009/files/radar_predictv2/results.tar.gz

# %% [markdown]
# step06 see the map

# %%
import webbrowser
file_path = "map5.html"
webbrowser.open(file_path)
# Out:
# True

# %% [markdown]
# http://103.254.67.181:10009/notebooks/radar_predictv3/map5.html
