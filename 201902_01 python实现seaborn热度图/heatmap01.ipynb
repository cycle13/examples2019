# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = np.random.rand(3, 3)
sns.heatmap(data)

# %%
ndata = np.random.randn(3,3)
print(ndata)
sns.heatmap(ndata, center=0)
# Out:
# [[-0.16133279  2.20884161 -2.81609434]
#  [ 0.85880124  0.73200261  0.17806416]
#  [-0.68600352  0.15565429  0.98521499]]

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
# pivot() 可以将dataframe转换为行列式矩阵 并指定每个元素的存储值
flights = flights.pivot(index='month', columns='year',  values='passengers')
# print(flights)
plt.figure(figsize=(10,6))
ax = sns.heatmap(flights, fmt='d', linewidths=.5)
# fmt设置字体模式  linewidth设置每个小方格的间距 线宽

# %%
plt.figure(figsize=(10,6))
ax = sns.heatmap(flights, fmt='d', linewidths=.5, cmap='YlGnBu')
