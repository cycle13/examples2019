# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
y = np.random.randint(1,100,32*32)
y = y.reshape((32,32))
df = pd.DataFrame(y,columns=[x for x in range(32)])
sns.heatmap(df,annot=True)
plt.show()
